# %% [markdown]
# <a href="https://colab.research.google.com/github/Amjad-Bin-Aslam/Data-Analysis-Practice/blob/main/05_Pandas/02_Pandas_Exercise.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # DataFrames
# A DataFrame is a 2D table (rows + columns), just like an Excel sheet or SQL table.
#
# * Every single row or column in data frame is called series.

# %% [markdown]
# # Creating DataFrame

# %%
import pandas as pd
import numpy as np

# %%
# using list
student_list = [
    [100,80,10],
    [90,70,7],
    [120,100,14],
    [80,50,2]
]
student_list # 2D list
student = pd.DataFrame(student_list,columns=["iq","marks","package"])
print(student)
# Out:
#     iq  marks  package
# 0  100     80       10
# 1   90     70        7
# 2  120    100       14
# 3   80     50        2

# %%
# using dict
student_dict = {
    'iq': [100,90,120,80],
    'marks': [80,70,100,50],
    'package': [10,7,14,2]
}
dataFrame = pd.DataFrame(student_dict)
print(dataFrame)
print(type(dataFrame))
# Out:
#     iq  marks  package
# 0  100     80       10
# 1   90     70        7
# 2  120    100       14
# 3   80     50        2
# <class 'pandas.core.frame.DataFrame'>

# %%
# using read_csv
matches = pd.read_csv('/content/matches.csv')
movies = pd.read_csv('/content/movies.csv')
diabetes = pd.read_csv('/content/diabetes.csv')
runs = pd.read_csv('/content/batsman_runs.csv')

# %% [markdown]
# # DataFrame Attributes

# %% [markdown]
# ### .shape
# It is about that how many no. of rows and columns are in a DataFrame.

# %%
movies.shape
# Out:
# (971, 18)

# %% [markdown]
# ## .dtypes
# It gives data type of columns.

# %%
movies.dtypes
# Out:
# title_x              object
# imdb_id              object
# poster_path          object
# wiki_link            object
# title_y              object
# original_title       object
# is_adult              int64
# year_of_release       int64
# runtime              object
# genres               object
# imdb_rating         float64
# imdb_votes            int64
# story                object
# summary              object
# tagline              object
# actors               object
# wins_nominations     object
# release_date         object
# dtype: object

# %% [markdown]
# ## .index
# By default it return range of index that starts from 0.
# Index number can be modified.

# %%
matches.index
# Out:
# RangeIndex(start=0, stop=950, step=1)

# %%
data = {
    'Name': ['John', 'Alice', 'Bob'],
    'Age': [25, 30, 22]
}
df = pd.DataFrame(data, index=['user1', 'user2', 'user3'])
print(df.index)
print(df.loc['user2'])
# Out:
# Index(['user1', 'user2', 'user3'], dtype='object')
# Name    Alice
# Age        30
# Name: user2, dtype: object

# %% [markdown]
# ## .columns
# It fetch the name of all column from Data set.

# %%
dataFrame.columns
# Out:
# Index(['iq', 'marks', 'package'], dtype='object')

# %% [markdown]
# ## .values
# Fetch all values from DataSet/DataFrame

# %%
print(student_list)
print("-----Printig tha values from DataFrame-----")
student_df = pd.DataFrame(student_list)
student_df.values
# Out:
# [[100, 80, 10], [90, 70, 7], [120, 100, 14], [80, 50, 2]]
# -----Printig tha values from DataFrame-----
# array([[100,  80,  10],
#        [ 90,  70,   7],
#        [120, 100,  14],
#        [ 80,  50,   2]])

# %% [markdown]
# ## .hasnans
# * Check for missig values in column

# %%
matches['City'].hasnans
# Out:
# True

# %% [markdown]
# # DataFrame Methods
# * A method is attached to an object.
# * It works on that object.

# %% [markdown]
# ## head() and tail()
# * by default head() return data of top five element from dataFrame
# * by default tail() return data of five element from last of data set.

# %%
# head()
matches.head(2)
# tail()
matches.tail(2)
# Out:
#          ID        City        Date   Season MatchNumber  \
# 948  335983  Chandigarh  2008-04-19  2007/08           2
# 949  335982   Bangalore  2008-04-18  2007/08           1
#
#                            Team1                  Team2  \
# 948              Kings XI Punjab    Chennai Super Kings
# 949  Royal Challengers Bangalore  Kolkata Knight Riders
#
#                                           Venue                   TossWinner  \
# 948  Punjab Cricket Association Stadium, Mohali          Chennai Super Kings
# 949                       M Chinnaswamy Stadium  Royal Challengers Bangalore
#
#     TossDecision SuperOver            WinningTeam WonBy  Margin method  \
# 948          bat         N    Chennai Super Kings  Runs    33.0    NaN
# 949        field         N  Kolkata Knight Riders  Runs   140.0    NaN
#
#     Player_of_Match                                       Team1Players  \
# 948      MEK Hussey  ['K Goel', 'JR Hopes', 'KC Sangakkara', 'Yuvra...
# ...

# %% [markdown]
# ## sample()
# Randomy fetch a single row from DataFrame.
# By default this method just fetch single row but we can change number of rows.

# %%
movies.sample(2)
# Out:
#                   title_x    imdb_id  \
# 969   Kurbaan (2009 film)  tt1185442
# 676  Chaar Din Ki Chandni  tt2191641
#
#                                            poster_path  \
# 969  https://upload.wikimedia.org/wikipedia/en/thum...
# 676                                                NaN
#
#                                              wiki_link               title_y  \
# 969  https://en.wikipedia.org/wiki/Kurbaan_(2009_film)               Kurbaan
# 676  https://en.wikipedia.org/wiki/Chaar_Din_Ki_Cha...  Chaar Din Ki Chandni
#
#            original_title  is_adult  year_of_release runtime  \
# 969               Kurbaan         0             2009     161
# 676  Chaar Din Ki Chandni         0             2012     131
#
#                  genres  imdb_rating  imdb_votes  \
# 969  Action|Crime|Drama          5.7        4351
# 676      Comedy|Romance          4.1         374
#
#                                                  story  \
# ...

# %% [markdown]
# ## info()
# Prints the consice summary of DataFrame

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 971 entries, 0 to 970
# Data columns (total 18 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   title_x           971 non-null    object
#  1   imdb_id           971 non-null    object
#  2   poster_path       925 non-null    object
#  3   wiki_link         971 non-null    object
#  4   title_y           971 non-null    object
#  5   original_title    971 non-null    object
#  6   is_adult          971 non-null    int64
#  7   year_of_release   971 non-null    int64
#  8   runtime           971 non-null    object
#  9   genres            971 non-null    object
#  10  imdb_rating       971 non-null    float64
#  11  imdb_votes        971 non-null    int64
#  12  story             960 non-null    object
#  13  summary           970 non-null    object
#  14  tagline           287 non-null    object
#  15  actors            968 non-null    object
# ...

# %% [markdown]
# ## describe()
# that method return description of DataFrame.
# It return mathematical summary of DataFrame

# %%
movies.describe()
# Out:
#        is_adult  year_of_release  imdb_rating    imdb_votes
# count     971.0       971.000000   971.000000     971.00000
# mean        0.0      2014.061792     5.674356    6195.22760
# std         0.0         3.004857     1.587980   16009.22518
# min         0.0      2008.000000     0.000000       0.00000
# 25%         0.0      2012.000000     4.600000     258.50000
# 50%         0.0      2014.000000     5.700000    1369.00000
# 75%         0.0      2017.000000     6.900000    5428.50000
# max         0.0      2019.000000     9.400000  310481.00000

# %% [markdown]
# ## isnull()
# * It check for the null values in the DataFrame and return boolean values.
# * Work on both DataFrame and Series.

# %%
print(movies.isnull().sum())
# Out:
# title_x               0
# imdb_id               0
# poster_path          46
# wiki_link             0
# title_y               0
# original_title        0
# is_adult              0
# year_of_release       0
# runtime               0
# genres                0
# imdb_rating           0
# imdb_votes            0
# story                11
# summary               1
# tagline             684
# actors                3
# wins_nominations    552
# release_date         55
# dtype: int64

# %% [markdown]
# ## duplicated()
# This print whether there are duplicated values in DataFrame or not.

# %%
print(movies.duplicated().sum())
# Out:
# 0

# %% [markdown]
# ## rename()
# Use to rename column names in DataFrame.
# To change the name permanantly we have to use the inplace parameter.

# %%
print("-----Before raname")
print(student)
print("-----After rename-----")
student.rename(columns={'marks':'std_marks'})
# Out:
# -----Before raname
#     iq  marks  package
# 0  100     80       10
# 1   90     70        7
# 2  120    100       14
# 3   80     50        2
# -----After rename-----
#     iq  std_marks  package
# 0  100         80       10
# 1   90         70        7
# 2  120        100       14
# 3   80         50        2

# %% [markdown]
# ## astype()
# It is use to change the data type of columns.

# %%
# matches.info()
matches['ID'] = matches['ID'].astype('int32')
matches['Team1'] = matches['Team1'].astype('category')
matches['Team2'] = matches['Team2'].astype('category')

matches.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 950 entries, 0 to 949
# Data columns (total 20 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   ID               950 non-null    int32
#  1   City             899 non-null    object
#  2   Date             950 non-null    object
#  3   Season           950 non-null    object
#  4   MatchNumber      950 non-null    object
#  5   Team1            950 non-null    category
#  6   Team2            950 non-null    category
#  7   Venue            950 non-null    object
#  8   TossWinner       950 non-null    object
#  9   TossDecision     950 non-null    object
#  10  SuperOver        946 non-null    object
#  11  WinningTeam      946 non-null    object
#  12  WonBy            950 non-null    object
#  13  Margin           932 non-null    float64
#  14  method           19 non-null     object
#  15  Player_of_Match  946 non-null    object
# ...

# %% [markdown]
# ## value_counts()
#
# * Print frequncy of each row in DataFrame.
# * Applicable on both Series and DataFrame.

# %%
marks = pd.DataFrame([
    [100,80,10],
    [90,70,7],
    [120,100,14],
    [80,70,14],
    [80,70,14]
], columns=['IQ', 'marks', 'package'])
marks.value_counts()
# Out:
# IQ   marks  package
# 80   70     14         2
# 90   70     7          1
# 100  80     10         1
# 120  100    14         1
# Name: count, dtype: int64

# %%
# find player who has won potm -> in finals and qualifiers
final_and_qualifier = matches[~matches['MatchNumber'].str.isdigit()]
player_of_Match = final_and_qualifier['Player_of_Match'].value_counts()
print(player_of_Match)
# Out:
# Player_of_Match
# F du Plessis         3
# SK Raina             3
# KA Pollard           3
# JJ Bumrah            2
# AB de Villiers       2
# MK Pandey            2
# M Vijay              2
# A Kumble             2
# YK Pathan            2
# SR Watson            2
# HH Pandya            1
# RM Patidar           1
# JC Buttler           1
# RR Pant              1
# KS Williamson        1
# MP Stoinis           1
# TA Boult             1
# SP Narine            1
# RD Gaikwad           1
# VR Iyer              1
# DA Miller            1
# Washington Sundar    1
# NM Coulter-Nile      1
# KV Sharma            1
# BCJ Cutting          1
# KH Pandya            1
# SA Yadav             1
# Rashid Khan          1
# AD Russell           1
# RG Sharma            1
# A Nehra              1
# DA Warner            1
# MC Henriques         1
# Harbhajan Singh      1
# BJ Hodge             1
# UT Yadav             1
# V Sehwag             1
# MS Bisla             1
# MEK Hussey           1
# ...

# %%
# Toss decision plot
toss_decision_count = matches['TossDecision'].value_counts()
toss_decision_count.plot(kind='pie')
# Out:
# <Axes: ylabel='count'>

# %%
# how many matches each team has played
palyed_by_team1 = matches['Team1'].value_counts()
palyed_by_team2 = matches['Team2'].value_counts()

played_by_each_team = palyed_by_team2 + palyed_by_team1
print(played_by_each_team.sort_values(ascending=False))
# Out:
# Mumbai Indians                 231
# Royal Challengers Bangalore    226
# Kolkata Knight Riders          223
# Chennai Super Kings            208
# Rajasthan Royals               192
# Kings XI Punjab                190
# Delhi Daredevils               161
# Sunrisers Hyderabad            152
# Deccan Chargers                 75
# Delhi Capitals                  63
# Pune Warriors                   46
# Gujarat Lions                   30
# Punjab Kings                    28
# Gujarat Titans                  16
# Rising Pune Supergiant          16
# Lucknow Super Giants            15
# Kochi Tuskers Kerala            14
# Rising Pune Supergiants         14
# Name: count, dtype: int64

# %% [markdown]
# ## sort_values()
# * Use to order/sort values in ascending or descending order
# * Applicable on both Series and DataFrame

# %%
# sort on the basis of single column
# sorting a column that consist missing(NaN) values then empty values will always come in the end of that column
movies.sort_values('title_x').head()
# Out:
#                     title_x    imdb_id  \
# 287            1920: London  tt5638500
# 723  1920: The Evil Returns  tt2222550
# 483    2 States (2014 film)  tt2372678
# 21                 22 Yards  tt9496212
# 530      3 A.M. (2014 film)  tt3720634
#
#                                            poster_path  \
# 287  https://upload.wikimedia.org/wikipedia/en/thum...
# 723  https://upload.wikimedia.org/wikipedia/en/e/e7...
# 483  https://upload.wikimedia.org/wikipedia/en/thum...
# 21   https://upload.wikimedia.org/wikipedia/en/thum...
# 530  https://upload.wikimedia.org/wikipedia/en/thum...
#
#                                              wiki_link  \
# 287          https://en.wikipedia.org/wiki/1920_London
# 723  https://en.wikipedia.org/wiki/1920:_The_Evil_R...
# 483  https://en.wikipedia.org/wiki/2_States_(2014_f...
# 21              https://en.wikipedia.org/wiki/22_Yards
# 530   https://en.wikipedia.org/wiki/3_A.M._(2014_film)
#
# ...

# %%
# sorting on the basis of multiple columns
movies.sort_values(['year_of_release','title_x'])
# Out:
#                       title_x     imdb_id  \
# 875                Antardwand   tt1722425
# 933                    Firaaq   tt1263679
# 929              Little Zizou   tt1119188
# 954                Phir Kabhi   tt1236441
# 550               Rang Rasiya   tt1239276
# ..                        ...         ...
# 64                Ujda Chaman  tt11046300
# 0    Uri: The Surgical Strike   tt8291224
# 3             Why Cheat India   tt8108208
# 60         Yaaram (2019 film)  tt11007050
# 73         Yeh Saali Aashiqui  tt10443846
#
#                                            poster_path  \
# 875  https://upload.wikimedia.org/wikipedia/en/thum...
# 933  https://upload.wikimedia.org/wikipedia/en/9/93...
# 929  https://upload.wikimedia.org/wikipedia/en/thum...
# 954  https://upload.wikimedia.org/wikipedia/en/2/2f...
# 550  https://upload.wikimedia.org/wikipedia/en/thum...
# ..                                                 ...
# 64   https://upload.wikimedia.org/wikipedia/en/thum...
# ...

# %% [markdown]
# ## rank()
# * use to rank data on the basis of column values
# * It is only applicable on Series

# %%
runs.sample(5)
# Out:
#               batter  batsman_run
# 514  SS Prabhudessai           67
# 526    Shahid Afridi           81
# 494       SK Trivedi           42
# 370    Navdeep Saini           33
# 32          AD Hales          148

# %%
runs['batsman_rank'] = runs['batsman_run'].rank(ascending=False)
runs.sort_values('batsman_rank').head(5)
# Out:
#         batter  batsman_run  batsman_rank
# 569    V Kohli         6634           1.0
# 462   S Dhawan         6244           2.0
# 130  DA Warner         5883           3.0
# 430  RG Sharma         5881           4.0
# 493   SK Raina         5536           5.0

# %% [markdown]
# ## sort_index()
# * use to sort data on the basis of index
# * It is applicable on both Series and DataFrame

# %%
marks = {
    'maths': 70,
    'english':57,
    'science': 89,
    'urdu': 100
}
marks_series = pd.Series(marks)
print(marks_series)
print("----After sorting tha data-----")
print(marks_series.sort_index(ascending=False))
# Out:
# maths       70
# english     57
# science     89
# urdu       100
# dtype: int64
# ----After sorting tha data-----
# urdu       100
# science     89
# maths       70
# english     57
# dtype: int64

# %%
movies.sort_index(ascending=False).head(5)
# Out:
#                  title_x    imdb_id  \
# 970          De Dana Dan  tt1255951
# 969  Kurbaan (2009 film)  tt1185442
# 968             Tum Mile  tt1522329
# 967     Jail (2009 film)  tt1245774
# 966        London Dreams  tt0486615
#
#                                            poster_path  \
# 970  https://upload.wikimedia.org/wikipedia/en/thum...
# 969  https://upload.wikimedia.org/wikipedia/en/thum...
# 968  https://upload.wikimedia.org/wikipedia/en/thum...
# 967  https://upload.wikimedia.org/wikipedia/en/thum...
# 966  https://upload.wikimedia.org/wikipedia/en/thum...
#
#                                              wiki_link        title_y  \
# 970          https://en.wikipedia.org/wiki/De_Dana_Dan    De Dana Dan
# 969  https://en.wikipedia.org/wiki/Kurbaan_(2009_film)        Kurbaan
# 968             https://en.wikipedia.org/wiki/Tum_Mile       Tum Mile
# 967     https://en.wikipedia.org/wiki/Jail_(2009_film)           Jail
# ...

# %% [markdown]
# ## set_index()
# * use to set the custom index
# * It is only applicable in DataFrame

# %%
# runs.head(2)
runs.set_index('batter',inplace=True)

# %% [markdown]
# ## reset_index()
#
# * It is opposite of set_index() method
# * It is applicable on both Series and DataFrame.

# %%
runs.head(2)
runs.reset_index().head(2)
# Out:
#            batter  batsman_run  batsman_rank
# 0  A Ashish Reddy          280         166.5
# 1        A Badoni          161         226.0

# %%
# how to make new index without loosing the existing one
runs.reset_index().set_index('batsman_rank').head(2)
# Out:
#                       batter  batsman_run
# batsman_rank
# 166.5         A Ashish Reddy          280
# 226.0               A Badoni          161

# %%
runs.head(2)
# Out:
#                 batsman_run  batsman_rank
# batter
# A Ashish Reddy          280         166.5
# A Badoni                161         226.0

# %%
# convert from series to dataframe using reset_index
marks_series.reset_index()
# Out:
#      index    0
# 0    maths   70
# 1  english   57
# 2  science   89
# 3     urdu  100

# %% [markdown]
# ## rename()
#
# * It is used to rename the column name.
# * It is only applicable to DataFrame

# %%
movies.rename(columns={'imdb_id': 'imdb','poster_path':'poster_link'}).head(2)
# Out:
#                     title_x       imdb  \
# 0  Uri: The Surgical Strike  tt8291224
# 1             Battalion 609  tt9472208
#
#                                          poster_link  \
# 0  https://upload.wikimedia.org/wikipedia/en/thum...
# 1                                                NaN
#
#                                            wiki_link  \
# 0  https://en.wikipedia.org/wiki/Uri:_The_Surgica...
# 1        https://en.wikipedia.org/wiki/Battalion_609
#
#                     title_y            original_title  is_adult  \
# 0  Uri: The Surgical Strike  Uri: The Surgical Strike         0
# 1             Battalion 609             Battalion 609         0
#
#    year_of_release runtime            genres  imdb_rating  imdb_votes  \
# 0             2019     138  Action|Drama|War          8.4       35112
# 1             2019     131               War          4.1          73
#
#                                                story  \
# ...

# %% [markdown]
# ## unique()
# * It use to fetch the unique values.
# * It is only work for Series
# * count missing values

# %%
temp = pd.Series([1,1,2,3,4,3,5,5,6,7,7])
temp.unique()
# Out:
# array([1, 2, 3, 4, 5, 6, 7])

# %%
len(matches['Season'].unique())
# Out:
# 15

# %% [markdown]
# ## nunique()
# * return count of unique values
# * Applicable on both Series and DataFrame.
# * Does not count the missing values.

# %%
matches['Season'].nunique()
# Out:
# 15

# %% [markdown]
# ## dropna
# * use to drop the missing values in data set
# * work on both DataFrame and Series

# %%
data = {
    "Name": ["Ali", "Sara", "Ahmed", "Zara", "Usman"],
    "Age": [21, np.nan, 23, 20, np.nan],
    "Marks": [85, 90, np.nan, 70, 88],
    "City": ["Lahore", "Karachi", np.nan, "Islamabad", "Lahore"]
}
student_data = pd.DataFrame(data)
student_data
# Out:
#     Name   Age  Marks       City
# 0    Ali  21.0   85.0     Lahore
# 1   Sara   NaN   90.0    Karachi
# 2  Ahmed  23.0    NaN        NaN
# 3   Zara  20.0   70.0  Islamabad
# 4  Usman   NaN   88.0     Lahore

# %%
student_data.dropna()
# Out:
#    Name   Age  Marks       City
# 0   Ali  21.0   85.0     Lahore
# 3  Zara  20.0   70.0  Islamabad

# %%
# Remove rows where all columns are NaN (completely empty rows).
student_data.dropna(how='all')
# Out:
#     Name   Age  Marks       City
# 0    Ali  21.0   85.0     Lahore
# 1   Sara   NaN   90.0    Karachi
# 2  Ahmed  23.0    NaN        NaN
# 3   Zara  20.0   70.0  Islamabad
# 4  Usman   NaN   88.0     Lahore

# %%
# Remove all rows where the 'Marks' column has NaN (missing value).
student_data.dropna(subset=['Marks'])
# Out:
#     Name   Age  Marks       City
# 0    Ali  21.0   85.0     Lahore
# 1   Sara   NaN   90.0    Karachi
# 3   Zara  20.0   70.0  Islamabad
# 4  Usman   NaN   88.0     Lahore

# %% [markdown]
# ## fillna()
# * use to fill missing values (NaN)
# * work on both DataFrame and Series

# %%
student_data['Age'].fillna('unknown')
# Out:
# 0       21.0
# 1    unknown
# 2       23.0
# 3       20.0
# 4    unknown
# Name: Age, dtype: object

# %%
# forward fill
student_data['City'].fillna(method='ffill')
# Out:
# /tmp/ipython-input-973079766.py:2: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   student_data['City'].fillna(method='ffill')
# 0       Lahore
# 1      Karachi
# 2      Karachi
# 3    Islamabad
# 4       Lahore
# Name: City, dtype: object

# %%
# backward fill
student_data['City'].fillna(method="bfill")
# Out:
# /tmp/ipython-input-50159156.py:2: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   student_data['City'].fillna(method="bfill")
# 0       Lahore
# 1      Karachi
# 2    Islamabad
# 3    Islamabad
# 4       Lahore
# Name: City, dtype: object

# %% [markdown]
# ## drop_duplicates()
# * It removes duplicate rows from a DataFrame (or Series) and keeps only the first occurrence by default.

# %%
data = {
    "Name": ["Ali", "Sara", "Ali", "Zara", "Sara"],
    "Age": [21, 22, 21, 20, 22],
    "Marks": [85, 90, 85, 70, 90]
}
df = pd.DataFrame(data)

# %%
df.drop_duplicates() # remove the duplicate row (Sara)
# Out:
#    Name  Age  Marks
# 0   Ali   21     85
# 1  Sara   22     90
# 3  Zara   20     70

# %%
# find the last match played by virat kohli in Delhi
matches['all_players'] = matches['Team1Players'] + matches['Team2Players']

# %%
def did_kohli_play(player_list):
  return 'V Kohli' in player_list

# %%
matches['did_kohli_play'] = matches['all_players'].apply(did_kohli_play)
matches[(matches['City'] == "Delhi") & (matches['did_kohli_play'] == True)].drop_duplicates(subset=['City','did_kohli_play'],keep='first')
# Out:
#           ID   City        Date Season MatchNumber           Team1  \
# 208  1178421  Delhi  2019-04-28   2019          46  Delhi Capitals
#
#                            Team2                 Venue      TossWinner  \
# 208  Royal Challengers Bangalore  Arun Jaitley Stadium  Delhi Capitals
#
#     TossDecision  ... WonBy Margin method  Player_of_Match  \
# 208          bat  ...  Runs   16.0    NaN         S Dhawan
#
#                                           Team1Players  \
# 208  ['PP Shaw', 'S Dhawan', 'SS Iyer', 'RR Pant', ...
#
#                                           Team2Players       Umpire1  \
# 208  ['PA Patel', 'V Kohli', 'AB de Villiers', 'S D...  BNJ Oxenford
#
#                    Umpire2                                        all_players  \
# 208  KN Ananthapadmanabhan  ['PP Shaw', 'S Dhawan', 'SS Iyer', 'RR Pant', ...
#
#     did_kohli_play
# 208           True
#
# [1 rows x 22 columns]

# %% [markdown]
# ## drop()
# * It is used to drop/delete the column.
# * Applicable on both DataFrame and Series

# %%
temp = pd.Series([10,2,3,16,45,78,10])
temp
# Out:
# 0    10
# 1     2
# 2     3
# 3    16
# 4    45
# 5    78
# 6    10
# dtype: int64

# %%
# Drop a row using the index number from a series
temp.drop(index=[0,6])
# Out:
# 1     2
# 2     3
# 3    16
# 4    45
# 5    78
# dtype: int64

# %%
student_data
# Out:
#     Name   Age  Marks       City
# 0    Ali  21.0   85.0     Lahore
# 1   Sara   NaN   90.0    Karachi
# 2  Ahmed  23.0    NaN        NaN
# 3   Zara  20.0   70.0  Islamabad
# 4  Usman   NaN   88.0     Lahore

# %%
# Drop a column from DataFrame using the column name
student_data.drop(columns=['City'])
# Out:
#     Name   Age  Marks
# 0    Ali  21.0   85.0
# 1   Sara   NaN   90.0
# 2  Ahmed  23.0    NaN
# 3   Zara  20.0   70.0
# 4  Usman   NaN   88.0

# %%
# Drop a row from dataFrame using the index number
student_data.drop(index=[0])
# Out:
#     Name   Age  Marks       City
# 1   Sara   NaN   90.0    Karachi
# 2  Ahmed  23.0    NaN        NaN
# 3   Zara  20.0   70.0  Islamabad
# 4  Usman   NaN   88.0     Lahore

# %% [markdown]
# ## apply()
# * apply() is used to apply a function to each element, row, or column of data.
# * Works on both DataFrame and Series.
# * It applies a function to each value of the Series.
# * It applies a function to rows or columns of DataFrame.

# %%
# apply() for series
ages = pd.Series([22,21,23])

# increase each age by 1
ages.apply(lambda x: x+ 1)
# Out:
# 0    23
# 1    22
# 2    24
# dtype: int64

# %%
# apply() for DataFrame
student_data
student_data['Marks'].apply(lambda x: x +5)
# Out:
# 0    90.0
# 1    95.0
# 2     NaN
# 3    75.0
# 4    93.0
# Name: Marks, dtype: float64

# %% [markdown]
# # Mathematical Methods

# %%
# sum
print("-----column-wise sum-------")
print(student.sum())
print("----row-wise sum-----")
print(student.sum(axis=1))
print("------sum of specific column------")
print(student['marks'].sum())
# Out:
# -----column-wise sum-------
# iq         390
# marks      300
# package     33
# dtype: int64
# ----row-wise sum-----
# 0    190
# 1    167
# 2    234
# 3    132
# dtype: int64
# ------sum of specific column------
# 300

# %%
# mean (can be column-wise and row-wise)
student.mean()
# Out:
# iq         97.50
# marks      75.00
# package     8.25
# dtype: float64

# %%
# min (can be col-wise and row-wise)
student.min()
# Out:
# iq         80
# marks      50
# package     2
# dtype: int64

# %%
# max (can be col-wise and row-wise)
print("-----max of all columns-----")
print(student.max())
print("-----max value from specific column-----")
print("maximum marks: ",student['marks'].max())
# Out:
# -----max of all columns-----
# iq         120
# marks      100
# package     14
# dtype: int64
# -----max value from specific column-----
# maximum marks:  100

# %% [markdown]
# # Selecting cols from a DataFrame

# %%
# fetching single column
movies['actors'].head()
# Out:
# 0    Vicky Kaushal|Paresh Rawal|Mohit Raina|Yami Ga...
# 1    Vicky Ahuja|Shoaib Ibrahim|Shrikant Kamat|Elen...
# 2    Anupam Kher|Akshaye Khanna|Aahana Kumra|Atul S...
# 3    Emraan Hashmi|Shreya Dhanwanthary|Snighdadeep ...
# 4    Mona Ambegaonkar|Ananth Narayan Mahadevan|Deva...
# Name: actors, dtype: object

# %%
matches['Venue'].head()
# Out:
# 0    Narendra Modi Stadium, Ahmedabad
# 1    Narendra Modi Stadium, Ahmedabad
# 2               Eden Gardens, Kolkata
# 3               Eden Gardens, Kolkata
# 4            Wankhede Stadium, Mumbai
# Name: Venue, dtype: object

# %%
# Fetching multiple columns
movies[['title_x','year_of_release','actors']].head()
# Out:
#                                 title_x  year_of_release  \
# 0              Uri: The Surgical Strike             2019
# 1                         Battalion 609             2019
# 2  The Accidental Prime Minister (film)             2019
# 3                       Why Cheat India             2019
# 4                       Evening Shadows             2018
#
#                                               actors
# 0  Vicky Kaushal|Paresh Rawal|Mohit Raina|Yami Ga...
# 1  Vicky Ahuja|Shoaib Ibrahim|Shrikant Kamat|Elen...
# 2  Anupam Kher|Akshaye Khanna|Aahana Kumra|Atul S...
# 3  Emraan Hashmi|Shreya Dhanwanthary|Snighdadeep ...
# 4  Mona Ambegaonkar|Ananth Narayan Mahadevan|Deva...

# %% [markdown]
# # Selecting rows from DataFrame
# * iloc - searches using index position
# * loc - searches using index labels

# %%
student_dict = {
    'name': ['amjad','zain','ahmad','talha'],
    'iq': [100,90,120,80],
    'marks': [80,90,100,70],
    'package': [10,7,14,4]
}
student_df1 = pd.DataFrame(student_dict)
student_df1.set_index('name', inplace=True) # set name column as index number
print(student_df1)
# Out:
#         iq  marks  package
# name
# amjad  100     80       10
# zain    90     90        7
# ahmad  120    100       14
# talha   80     70        4

# %%
# single row
matches.iloc[0]
# Out:
# ID                                                           1312200
# City                                                       Ahmedabad
# Date                                                      2022-05-29
# Season                                                          2022
# MatchNumber                                                    Final
# Team1                                               Rajasthan Royals
# Team2                                                 Gujarat Titans
# Venue                               Narendra Modi Stadium, Ahmedabad
# TossWinner                                          Rajasthan Royals
# TossDecision                                                     bat
# SuperOver                                                          N
# WinningTeam                                           Gujarat Titans
# WonBy                                                        Wickets
# Margin                                                           7.0
# ...

# %%
# multiple rows
movies.iloc[0:4]
# Out:
#                                 title_x    imdb_id  \
# 0              Uri: The Surgical Strike  tt8291224
# 1                         Battalion 609  tt9472208
# 2  The Accidental Prime Minister (film)  tt6986710
# 3                       Why Cheat India  tt8108208
#
#                                          poster_path  \
# 0  https://upload.wikimedia.org/wikipedia/en/thum...
# 1                                                NaN
# 2  https://upload.wikimedia.org/wikipedia/en/thum...
# 3  https://upload.wikimedia.org/wikipedia/en/thum...
#
#                                            wiki_link  \
# 0  https://en.wikipedia.org/wiki/Uri:_The_Surgica...
# 1        https://en.wikipedia.org/wiki/Battalion_609
# 2  https://en.wikipedia.org/wiki/The_Accidental_P...
# 3      https://en.wikipedia.org/wiki/Why_Cheat_India
#
#                          title_y                 original_title  is_adult  \
# 0       Uri: The Surgical Strike       Uri: The Surgical Strike         0
# ...

# %%
# fancy indexing
movies.iloc[[1,3,4]]
# Out:
#            title_x    imdb_id  \
# 1    Battalion 609  tt9472208
# 3  Why Cheat India  tt8108208
# 4  Evening Shadows  tt6028796
#
#                                          poster_path  \
# 1                                                NaN
# 3  https://upload.wikimedia.org/wikipedia/en/thum...
# 4                                                NaN
#
#                                        wiki_link          title_y  \
# 1    https://en.wikipedia.org/wiki/Battalion_609    Battalion 609
# 3  https://en.wikipedia.org/wiki/Why_Cheat_India  Why Cheat India
# 4  https://en.wikipedia.org/wiki/Evening_Shadows  Evening Shadows
#
#     original_title  is_adult  year_of_release runtime       genres  \
# 1    Battalion 609         0             2019     131          War
# 3  Why Cheat India         0             2019     121  Crime|Drama
# 4  Evening Shadows         0             2018     102        Drama
#
#    imdb_rating  imdb_votes                                              story  \
# ...

# %%
# single row
student_df1.loc['amjad']
# Out:
# iq         100
# marks       80
# package     10
# Name: amjad, dtype: int64

# %%
# multiple rows
student_df1.loc['amjad':'ahmad'] # first row and last row, both are included
# Out:
#         iq  marks  package
# name
# amjad  100     80       10
# zain    90     90        7
# ahmad  120    100       14

# %%
# fancy indexing
student_df1.loc[['amjad','talha']]
# Out:
#         iq  marks  package
# name
# amjad  100     80       10
# talha   80     70        4

# %% [markdown]
# # Selecting both rows and cols simaltaneously.

# %%
movies.iloc[0:3,0:3] # first three rows with first two cols
# Out:
#                                 title_x    imdb_id  \
# 0              Uri: The Surgical Strike  tt8291224
# 1                         Battalion 609  tt9472208
# 2  The Accidental Prime Minister (film)  tt6986710
#
#                                          poster_path
# 0  https://upload.wikimedia.org/wikipedia/en/thum...
# 1                                                NaN
# 2  https://upload.wikimedia.org/wikipedia/en/thum...

# %% [markdown]
# # Filtering DataFrame
# * Filtering data means selecting only the rows that match certain conditions from a dataset.
# * You keep what you need and remove what you don’t.

# %%
# find all the final winners
final = matches['MatchNumber'] == "Final"
new_df = matches[final]
new_df[['Season','WinningTeam']]
# Out:
#       Season            WinningTeam
# 0       2022         Gujarat Titans
# 74      2021    Chennai Super Kings
# 134  2020/21         Mumbai Indians
# 194     2019         Mumbai Indians
# 254     2018    Chennai Super Kings
# 314     2017         Mumbai Indians
# 373     2016    Sunrisers Hyderabad
# 433     2015         Mumbai Indians
# 492     2014  Kolkata Knight Riders
# 552     2013         Mumbai Indians
# 628     2012  Kolkata Knight Riders
# 702     2011    Chennai Super Kings
# 775  2009/10    Chennai Super Kings
# 835     2009        Deccan Chargers
# 892  2007/08       Rajasthan Royals

# %%
# how many super over finishes have occured
matches[matches['SuperOver'] == "Y"].shape[0]
# Out:
# 14

# %%
# how many matches has csk won in kolkata
kolkata_matches = matches[matches['City'] == 'Kolkata']
kolkata_matches[kolkata_matches['WinningTeam'] == 'Chennai Super Kings'].shape[0]

# 2nd method to write this code
matches[(matches['City'] == "Kolkata") & (matches['WinningTeam'] == "Chennai Super Kings")].shape[0]
# Out:
# 5

# %%
matches.head(2)
# Out:
#         ID       City        Date Season  MatchNumber  \
# 0  1312200  Ahmedabad  2022-05-29   2022        Final
# 1  1312199  Ahmedabad  2022-05-27   2022  Qualifier 2
#
#                          Team1             Team2  \
# 0             Rajasthan Royals    Gujarat Titans
# 1  Royal Challengers Bangalore  Rajasthan Royals
#
#                               Venue        TossWinner TossDecision  ...  \
# 0  Narendra Modi Stadium, Ahmedabad  Rajasthan Royals          bat  ...
# 1  Narendra Modi Stadium, Ahmedabad  Rajasthan Royals        field  ...
#
#      WonBy Margin method  Player_of_Match  \
# 0  Wickets    7.0    NaN        HH Pandya
# 1  Wickets    7.0    NaN       JC Buttler
#
#                                         Team1Players  \
# 0  ['YBK Jaiswal', 'JC Buttler', 'SV Samson', 'D ...
# 1  ['V Kohli', 'F du Plessis', 'RM Patidar', 'GJ ...
#
#                                         Team2Players      Umpire1  \
# ...

# %%
# toss winner is match winner in percentage
total_matches = matches.shape[0]
print("Total number of matches: ",total_matches)

toss_winner_matches = matches[matches['TossWinner'] == matches['WinningTeam']]

toss_win_count = toss_winner_matches.shape[0]
print("Toss win count :", toss_win_count)

percentage = (toss_win_count/total_matches) * 100
print("Percentage: ",percentage)

# A short method to write this code
percentage = (matches[matches['TossWinner'] == matches['WinningTeam']].shape[0]/matches.shape[0]) * 100
print("Percentage by short code ",percentage)
# Out:
# Total number of matches:  950
# Toss win count : 489
# Percentage:  51.473684210526315
# Percentage by short code  51.473684210526315

# %%
# movies with rating highier than 8 amdb and votes > 10000
required = movies[(movies['imdb_rating'] > 8) & (movies['imdb_votes'] > 10000)].shape[0]
print(required)
# Out:
# 28

# %%
movies.head(2)
# Out:
#                     title_x    imdb_id  \
# 0  Uri: The Surgical Strike  tt8291224
# 1             Battalion 609  tt9472208
#
#                                          poster_path  \
# 0  https://upload.wikimedia.org/wikipedia/en/thum...
# 1                                                NaN
#
#                                            wiki_link  \
# 0  https://en.wikipedia.org/wiki/Uri:_The_Surgica...
# 1        https://en.wikipedia.org/wiki/Battalion_609
#
#                     title_y            original_title  is_adult  \
# 0  Uri: The Surgical Strike  Uri: The Surgical Strike         0
# 1             Battalion 609             Battalion 609         0
#
#    year_of_release runtime            genres  imdb_rating  imdb_votes  \
# 0             2019     138  Action|Drama|War          8.4       35112
# 1             2019     131               War          4.1          73
#
#                                                story  \
# ...

# %%
# Action movies with rating highier than 7.5
# mask1 = movies['genres'].str.contains("Actions")
mask1 = movies['genres'].str.split('|').apply(lambda x: "Action" in x)
mask2 = movies['imdb_rating'] > 7.5
movies[mask1 & mask2].shape[0]
# Out:
# 22

# %%
# write a function that can return the track of two teams each other
mi_vs_csk = matches[
    ((matches['Team1'] == "Mumbai Indians") & (matches['Team2'] == 'Chennai Super Kings'))
    |
    ((matches['Team1'] == "Chennai Super Kings") & (matches['Team2'] == "Mumbai Indians"))
]

total_matches = mi_vs_csk.shape[0]
print("Total matches: ",total_matches)

mi_wins = (mi_vs_csk['WinningTeam'] == "Mumbai Indians").sum()
print("Mumbai Indians Wins: ",mi_wins)

csk_wins = mi_vs_csk[mi_vs_csk['WinningTeam'] == "Chennai Super Kings"].shape[0]
print("CSK Wins: ", csk_wins)

mi_percentage = (mi_wins / total_matches) * 100
csk_percentage = (csk_wins / total_matches) * 100

print("MI Win %: ", round(mi_percentage,2))
print("CSK Win %: ", round(csk_percentage, 2))
# Out:
# Total matches:  34
# Mumbai Indians Wins:  20
# CSK Wins:  14
# MI Win %:  58.82
# CSK Win %:  41.18

# %% [markdown]
# # Adding new Columns in DataFrame

# %%
# new columns
movies['Type'] = 'Bollywood'
movies.head(2)
# Out:
#                     title_x    imdb_id  \
# 0  Uri: The Surgical Strike  tt8291224
# 1             Battalion 609  tt9472208
#
#                                          poster_path  \
# 0  https://upload.wikimedia.org/wikipedia/en/thum...
# 1                                                NaN
#
#                                            wiki_link  \
# 0  https://en.wikipedia.org/wiki/Uri:_The_Surgica...
# 1        https://en.wikipedia.org/wiki/Battalion_609
#
#                     title_y            original_title  is_adult  \
# 0  Uri: The Surgical Strike  Uri: The Surgical Strike         0
# 1             Battalion 609             Battalion 609         0
#
#    year_of_release runtime            genres  imdb_rating  imdb_votes  \
# 0             2019     138  Action|Drama|War          8.4       35112
# 1             2019     131               War          4.1          73
#
#                                                story  \
# ...

# %%
movies1 = movies.dropna() # Removes the all null values
movies1.shape
# Out:
# (144, 19)

# %%
# create new column from existing ones
movies1['lead actors'] = movies1['actors'].str.split('|').apply(lambda x:x[0])
movies1
# Out:
# /tmp/ipython-input-139330615.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   movies1['lead actors'] = movies1['actors'].str.split('|').apply(lambda x:x[0])
#                   title_x     imdb_id  \
# 11              Gully Boy   tt2395469
# 34          Yeh Hai India   tt5525846
# 37      Article 15 (film)  tt10324144
# 87                Aiyaary   tt6774212
# 96       Raid (2018 film)   tt7363076
# ..                    ...         ...
# 933                Firaaq   tt1263679
# 941  New York (2009 film)   tt1328634
# 962      Blue (2009 film)   tt1223922
# 965         Aladin (film)   tt1227762
# 969   Kurbaan (2009 film)   tt1185442
#
#                                            poster_path  \
# ...

# %% [markdown]
# # DataFrame Functions
# * A function is independent.
# * It is called directly usig its name.
